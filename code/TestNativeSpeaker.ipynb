# %%
import pandas as pd

# %%
# !gdown --id "19NQCGn3aq9ixYwJdhk1yFxprfRfiH8NN"
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=19NQCGn3aq9ixYwJdhk1yFxprfRfiH8NN
# To: /content/native_speaker.zip
# 100% 43.1M/43.1M [00:01<00:00, 42.6MB/s]

# %%
# !unzip "/content/native_speaker.zip"

# %%
df = pd.read_csv("/content/nattive.csv")

# %%
df
# Out:
#                     UtteranceID SpeakerID                        Transcription
# 0    38_5716_20170914202211.wav   38_5716                         嗨天气寒冷记得添衣保暖哦
# 1    38_5716_20170914202228.wav   38_5716      人的能耐再大大不过天阵雨转阴又变了天了天要下雨娘要嫁人由她去吧
# 2    38_5716_20170914202312.wav   38_5716                               播放二胡独奏
# 3    38_5716_20170914202319.wav   38_5716                                可是刮风了
# 4    38_5716_20170914202333.wav   38_5716  南阳持续降雨水深路滑出行一定要注意安全刚回家的路上我差点儿被冲进下水道
# ..                          ...       ...                                  ...
# 494  38_5718_20170915102138.wav   38_5718                               我回家去吃饭
# 495  38_5718_20170915102144.wav   38_5718                                 等我呢吧
# 496  38_5718_20170915102150.wav   38_5718                              你那天有时间呢
# 497  38_5718_20170915102158.wav   38_5718                             我是那个她李伟的
# 498  38_5718_20170915102206.wav   38_5718                               你真准备要呀
#
# [499 rows x 3 columns]

# %%
df = df.drop(columns=["SpeakerID"])

# %%
df["labels"] = 1

# %%
df[:10]
# Out:
#                   UtteranceID                        Transcription  labels
# 0  38_5716_20170914202211.wav                         嗨天气寒冷记得添衣保暖哦       1
# 1  38_5716_20170914202228.wav      人的能耐再大大不过天阵雨转阴又变了天了天要下雨娘要嫁人由她去吧       1
# 2  38_5716_20170914202312.wav                               播放二胡独奏       1
# 3  38_5716_20170914202319.wav                                可是刮风了       1
# 4  38_5716_20170914202333.wav  南阳持续降雨水深路滑出行一定要注意安全刚回家的路上我差点儿被冲进下水道       1
# 5  38_5716_20170914202341.wav                              播放雪莉的歌曲       1
# 6  38_5716_20170914202408.wav             我想这出最好歌曲把歌词发到网上请别人帮我作曲急急       1
# 7  38_5716_20170914202417.wav                       别说个大概齐 说具体是哪首歌       1
# 8  38_5716_20170914202426.wav                        除了自命不凡和爱是一种幸福       1
# 9  38_5716_20170914202435.wav                       有点儿急哎嘿是因为很喜欢他啊       1

# %%
df.iloc[0]
# Out:
# UtteranceID      38_5716_20170914202211.wav
# Transcription                  嗨天气寒冷记得添衣保暖哦
# labels                                    1
# Name: 0, dtype: object

# %%
# !pip install sklearn

# %%
import numpy as np
from sklearn.model_selection import train_test_split

train_df, test_df = train_test_split( df, test_size=0.3, random_state=42)

# %%
test_df
# Out:
#                     UtteranceID       Transcription  labels
# 460  38_5718_20170915101607.wav            我还是给你当姐姐       1
# 73   38_5718_20170914200441.wav              声音转换轻柔       1
# 231  38_5718_20170914205216.wav  今天天气很好可是我不知道怎么了很难过       1
# 175  38_5718_20170914204352.wav         小来怎么没有天气预报了       1
# 237  38_5718_20170915092858.wav          你告诉我今天珠海天气       1
# ..                          ...                 ...     ...
# 193  38_5718_20170914204639.wav       提醒大家明天早上九点半聚会       1
# 5    38_5716_20170914202341.wav             播放雪莉的歌曲       1
# 116  38_5718_20170914201846.wav     英文曲子都行越多越好尽量别中文       1
# 45   38_5718_20170914194315.wav              主座位升一点       1
# 16   38_5716_20170914202603.wav           放一下漂亮的在一起       1
#
# [150 rows x 3 columns]

# %%
negative_testset = test_df.copy()

# %%
negative_testset["Transcription"]
np.random.seed(1)
negative_testset["Transcription"] = np.random.permutation(negative_testset["Transcription"])

# %%
for i in range(len(test_df)):
  test_df["Transcription"].iloc[i]
  if negative_testset["Transcription"].iloc[i] == test_df["Transcription"].iloc[i]:
    print("true")

# %%
negative_testset["labels"] = 0

# %%
negative_testset
# Out:
#                     UtteranceID     Transcription  labels
# 460  38_5718_20170915101607.wav          播放朴宝英的歌曲       0
# 73   38_5718_20170914200441.wav     一天弹钢琴多少个小时最好呢       0
# 231  38_5718_20170914205216.wav     请给我播放沉默的证人第一集       0
# 175  38_5718_20170914204352.wav            播放玄奘的歌       0
# 237  38_5718_20170915092858.wav       还有雪是不是今天拍的呀       0
# ..                          ...               ...     ...
# 193  38_5718_20170914204639.wav            拨打李总电话       0
# 5    38_5716_20170914202341.wav              文昌空气       0
# 116  38_5718_20170914201846.wav          很想听音乐修今生       0
# 45   38_5718_20170914194315.wav        原来你只是报天气的呀       0
# 16   38_5716_20170914202603.wav  不要太多只要几首就好听太多懒得听       0
#
# [150 rows x 3 columns]

# %%
test_df = pd.concat([test_df,negative_testset],ignore_index=True)

# %%
test_df
# Out:
#                     UtteranceID       Transcription  labels
# 0    38_5718_20170915101607.wav            我还是给你当姐姐       1
# 1    38_5718_20170914200441.wav              声音转换轻柔       1
# 2    38_5718_20170914205216.wav  今天天气很好可是我不知道怎么了很难过       1
# 3    38_5718_20170914204352.wav         小来怎么没有天气预报了       1
# 4    38_5718_20170915092858.wav          你告诉我今天珠海天气       1
# ..                          ...                 ...     ...
# 295  38_5718_20170914204639.wav              拨打李总电话       0
# 296  38_5716_20170914202341.wav                文昌空气       0
# 297  38_5718_20170914201846.wav            很想听音乐修今生       0
# 298  38_5718_20170914194315.wav          原来你只是报天气的呀       0
# 299  38_5716_20170914202603.wav    不要太多只要几首就好听太多懒得听       0
#
# [300 rows x 3 columns]

# %%
test_df.to_csv('test_df_data.csv')

# %%
import shutil
shutil.move("test_df_data.csv","/content/drive/MyDrive")
# Out:
# '/content/drive/MyDrive/test_df_data.csv'

# %%
#for loop check model

# %%
dfa = pd.read_csv("/content/test_df_data.csv")
dfa
# Out:
#      Unnamed: 0                 UtteranceID       Transcription  labels
# 0             0  38_5718_20170915101607.wav            我还是给你当姐姐       1
# 1             1  38_5718_20170914200441.wav              声音转换轻柔       1
# 2             2  38_5718_20170914205216.wav  今天天气很好可是我不知道怎么了很难过       1
# 3             3  38_5718_20170914204352.wav         小来怎么没有天气预报了       1
# 4             4  38_5718_20170915092858.wav          你告诉我今天珠海天气       1
# ..          ...                         ...                 ...     ...
# 295         295  38_5718_20170914204639.wav              拨打李总电话       0
# 296         296  38_5716_20170914202341.wav                文昌空气       0
# 297         297  38_5718_20170914201846.wav            很想听音乐修今生       0
# 298         298  38_5718_20170914194315.wav          原来你只是报天气的呀       0
# 299         299  38_5716_20170914202603.wav    不要太多只要几首就好听太多懒得听       0
#
# [300 rows x 4 columns]

# %%
dfa = dfa.drop(columns=["Unnamed: 0"])

# %%
import librosa

# %%
def speech_file_to_array_fn(path):
    #bath = pathtowav(a["id"])
    speech_array, sampling_rate = librosa.load(path, sr=16_000)
    #batch["speech"] = speech_array
    #atch["sentence"] = batch["sentence"].upper()
    return speech_array

# %%
# !pip install datasets
# !pip install transformers

# %%
import torch
import librosa
from datasets import load_dataset
from transformers import Wav2Vec2ForCTC, Wav2Vec2Processor
import numpy as np

# %%
class Realwav:
  def __init__(self):
    MODEL_ID = "jonatasgrosman/wav2vec2-large-xlsr-53-chinese-zh-cn"
    self.processor = Wav2Vec2Processor.from_pretrained(MODEL_ID)
    self.model = Wav2Vec2ForCTC.from_pretrained(MODEL_ID)
  
  def sound_and_sentence(self,sound,sentence):
    inputs = self.processor(sound, sampling_rate=16_000, return_tensors="pt", padding=True)
    with torch.no_grad():
        logits = self.model(inputs.input_values, attention_mask=inputs.attention_mask).logits
    
    probs = torch.softmax(logits, dim=-1)
    ref_ids = self.processor(text=sentence)["input_ids"]
    scores = []
    ref_count = 0
    pred_ids = torch.argmax(logits[0], dim=-1)
    for seq_idx in range(pred_ids.shape[0]):
      if pred_ids[seq_idx] != 0:
        print(f"position of the word {sentence[ref_count]}: {seq_idx}")
        ref_id = ref_ids[ref_count]
        conf_score = probs[0, seq_idx, ref_id].tolist()
        scores.append(conf_score)
        print(conf_score)
        ref_count += 1
        if ref_count >= len(ref_ids):
          break
    #print("-" * 100)
    #print(scores)
    sentence_score = np.mean(scores)
    #print(sentence_score)
    return sentence_score, int(sentence_score > 0.5)

# %%
rw = Realwav()
# Out:
# ...
# /usr/local/lib/python3.10/dist-packages/transformers/configuration_utils.py:380: UserWarning: Passing `gradient_checkpointing` to a config initialization is deprecated and will be removed in v5 Transformers. Using `model.gradient_checkpointing_enable()` instead, or if you are using the `Trainer` API, pass `gradient_checkpointing=True` in your `TrainingArguments`.
#   warnings.warn(
# ...

# %%
dfa
# Out:
#                     UtteranceID       Transcription  labels
# 0    38_5718_20170915101607.wav            我还是给你当姐姐       1
# 1    38_5718_20170914200441.wav              声音转换轻柔       1
# 2    38_5718_20170914205216.wav  今天天气很好可是我不知道怎么了很难过       1
# 3    38_5718_20170914204352.wav         小来怎么没有天气预报了       1
# 4    38_5718_20170915092858.wav          你告诉我今天珠海天气       1
# ..                          ...                 ...     ...
# 295  38_5718_20170914204639.wav              拨打李总电话       0
# 296  38_5716_20170914202341.wav                文昌空气       0
# 297  38_5718_20170914201846.wav            很想听音乐修今生       0
# 298  38_5718_20170914194315.wav          原来你只是报天气的呀       0
# 299  38_5716_20170914202603.wav    不要太多只要几首就好听太多懒得听       0
#
# [300 rows x 3 columns]

# %%
def pathtowav(id):
  path = f"/content/native_speaker/{id}"
  return path

# %%
f1 = dfa["UtteranceID"][1]
id = pathtowav(f1)
print(type(id))
# Out:
# <class 'str'>

# %%
/content/native_speaker/38_5718_20170914204123.wav

# %%
#test class Realwav
sample = dfa.iloc[0]
id = sample["UtteranceID"]
sentence = sample["Transcription"]
pathwav = pathtowav(id)
filesound = speech_file_to_array_fn(pathwav)
output = rw.sound_and_sentence(filesound,sentence)
# Out:
# position of the word 我: 55
# 0.9999305009841919
# position of the word 还: 68
# 0.9994489550590515
# position of the word 是: 81
# 0.9997437596321106
# position of the word 给: 96
# 0.9998917579650879
# position of the word 你: 107
# 0.9985485672950745
# position of the word 当: 119
# 0.9997891783714294
# position of the word 姐: 131
# 0.04370630159974098
# position of the word 姐: 143
# 0.9313098788261414

# %%
predicts = []
for i in range(len(dfa)):
  sample = dfa.iloc[i]
  id = sample["UtteranceID"]
  sentence = sample["Transcription"]
  pathwav = pathtowav(id)
  filesound = speech_file_to_array_fn(pathwav)
  output = rw.sound_and_sentence(filesound,sentence)
  predicts.append(output)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9e7aae0e62f9> in <cell line: 2>()
#       1 predicts = []
# ----> 2 for i in range(len(dfa)):
#       3   sample = dfa.iloc[i]
#       4   id = sample["UtteranceID"]
#       5   sentence = sample["Transcription"]
#
# NameError: name 'dfa' is not defined

# %%
dfa["predicts"] = predicts

# %%
dfa.to_csv('test_predicts_native.csv')

# %%
#ครั้งใหม่

# %%
import pandas as pd

# %%
dfn = pd.read_csv("/content/test_predicts.csv")

# %%
dfn
# Out:
#      Unnamed: 0.1  Unnamed: 0      id                 sentence  labels  \
# 0               0           0  110173                        五       1
# 1               1           1  130426  大清河甚至决了堤防 ， 但这并不能算是有水 ；       1
# 2               2           2  110125      易卜生有一本思叫所做《国民的公敌》 ，       1
# 3               3           3  100319          是鹦鹉和留声机器都能做的事 。       1
# 4               4           4  110325           社会、国家是是时刻变迁的 ，       1
# ..            ...         ...     ...                      ...     ...
# 511           511         511  120055  大清河甚至决了堤防 ， 但这并不能算是有水 ；       0
# 512           512         512  120138            有种种种绝不相同的情形 。       0
# 513           513         513  130554                 可有讨论的吗 ？       0
# 514           514         514  130435          打倒了两千年尊崇的宗教传说 ！       0
# 515           515         515  100612          是鹦鹉和留声机器都能做的事 。       0
#
#      predict
# 0          0
# 1          0
# 2          0
# 3          1
# 4          0
# ..       ...
# ...

# %%
dfn["predict"][3]
# Out:
# 1

# %%
import numpy as np

# %%
xx = []
if dfn["labels"][3] == 1:
    if dfn["predict"][3] == 1:
      xx.append(1)
      print(xx)
# Out:
# [1]

# %%
y_true = []
for i in range(len(dfn["labels"])):
  if dfn["labels"][i] == 1:
    y_true.append(dfn["predict"][i])
  if dfn["labels"][i] == 0:
    if dfn["predict"][i] == 0:
      y_true.append(1)

# %%
for i in range(len(dfn["labels"])):
  if dfn["labels"][i] == 0:
    if dfn["predict"][i] == 0:
      dfn["predict"][i]=1
# Out:
# <ipython-input-39-a992fac870b2>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfn["predict"][i]=1

# %%
dfn
# Out:
#      Unnamed: 0.1  Unnamed: 0      id                 sentence  labels  \
# 0               0           0  110173                        五       1
# 1               1           1  130426  大清河甚至决了堤防 ， 但这并不能算是有水 ；       1
# 2               2           2  110125      易卜生有一本思叫所做《国民的公敌》 ，       1
# 3               3           3  100319          是鹦鹉和留声机器都能做的事 。       1
# 4               4           4  110325           社会、国家是是时刻变迁的 ，       1
# ..            ...         ...     ...                      ...     ...
# 511           511         511  120055  大清河甚至决了堤防 ， 但这并不能算是有水 ；       0
# 512           512         512  120138            有种种种绝不相同的情形 。       0
# 513           513         513  130554                 可有讨论的吗 ？       0
# 514           514         514  130435          打倒了两千年尊崇的宗教传说 ！       0
# 515           515         515  100612          是鹦鹉和留声机器都能做的事 。       0
#
#      predict
# 0          0
# 1          0
# 2          0
# 3          1
# 4          0
# ..       ...
# ...

# %%
y_pred = []
for i in range(len(dfn["labels"])):
  y_pred.append(dfn["predict"][i])
print(len(y_pred))
# Out:
# 516

# %%
y_pred = []
for i in range(len(dfn["labels"])):
  y_pred.append(dfn["predict"][i])
print(len(y_pred))

y_true = []
for i in range(len(dfn["id"])):
   y_true.append(dfn["labels"][i])

print(len(y_true))

y_true = np.array(y_true)
y_pred = np.array(y_pred)
# Out:
# 516
# 516

# %%
y_pred

# %%
y_true = []
for i in range(len(dfn["id"])):
   y_true.append(dfn["labels"][i])

print(len(y_true))
# Out:
# 516

# %%
y_true = np.array(y_true)
y_pred = np.array(y_pred)

# %%
print(y_true)
print(y_pred)

# %%
from sklearn.metrics import recall_score
recall_score(y_true, y_pred)
# Out:
# 0.2364341085271318

# %%
from sklearn.metrics import precision_score
precision_score(y_true, y_pred, average='macro')
# Out:
# 0.7835164835164835

# %%
from sklearn.metrics import f1_score
f1_score(y_true, y_pred, average='macro')
# Out:
# 0.5530739029312324

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/test_predicts_native.csv")

# %%
df
# Out:
#      Unnamed: 0                 UtteranceID       Transcription  labels  \
# 0             0  38_5718_20170915101607.wav            我还是给你当姐姐       1
# 1             1  38_5718_20170914200441.wav              声音转换轻柔       1
# 2             2  38_5718_20170914205216.wav  今天天气很好可是我不知道怎么了很难过       1
# 3             3  38_5718_20170914204352.wav         小来怎么没有天气预报了       1
# 4             4  38_5718_20170915092858.wav          你告诉我今天珠海天气       1
# ..          ...                         ...                 ...     ...
# 295         295  38_5718_20170914204639.wav              拨打李总电话       0
# 296         296  38_5716_20170914202341.wav                文昌空气       0
# 297         297  38_5718_20170914201846.wav            很想听音乐修今生       0
# 298         298  38_5718_20170914194315.wav          原来你只是报天气的呀       0
# 299         299  38_5716_20170914202603.wav    不要太多只要几首就好听太多懒得听       0
#
#      predicts
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1
# ...

# %%
n = len(df["labels"]==1)

# %%
n
# Out:
# 300

# %%
df
# Out:
#      Unnamed: 0                 UtteranceID       Transcription  labels  \
# 0             0  38_5718_20170915101607.wav            我还是给你当姐姐       1
# 1             1  38_5718_20170914200441.wav              声音转换轻柔       1
# 2             2  38_5718_20170914205216.wav  今天天气很好可是我不知道怎么了很难过       1
# 3             3  38_5718_20170914204352.wav         小来怎么没有天气预报了       1
# 4             4  38_5718_20170915092858.wav          你告诉我今天珠海天气       1
# ..          ...                         ...                 ...     ...
# 295         295  38_5718_20170914204639.wav              拨打李总电话       0
# 296         296  38_5716_20170914202341.wav                文昌空气       0
# 297         297  38_5718_20170914201846.wav            很想听音乐修今生       0
# 298         298  38_5718_20170914194315.wav          原来你只是报天气的呀       0
# 299         299  38_5716_20170914202603.wav    不要太多只要几首就好听太多懒得听       0
#
#      predicts
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1
# ...

# %%
correc=0
for i in range(len(df["labels"])):
  if(df["predicts"][i] == 1 ):
    correc +=1
    print(correc)

# %%
num = 0
for j in range(len(df["labels"])):
  if(df["labels"][j] == 1 ):
    num +=1
    print(num)

# %%
cor = 0
for j in range(len(df["labels"])):
  if(df["predicts"][j] == 1 ):
    cor +=1
    print(cor)

# %%
num
# Out:
# 0

# %%
cor = 0
for j in range(len(dfn["labels"])):
  if(dfn["predict"][j] == 1 ):
    cor +=1
    print(cor)

# %%
df
# Out:
#      Unnamed: 0                 UtteranceID       Transcription  labels  \
# 0             0  38_5718_20170915101607.wav            我还是给你当姐姐       1
# 1             1  38_5718_20170914200441.wav              声音转换轻柔       1
# 2             2  38_5718_20170914205216.wav  今天天气很好可是我不知道怎么了很难过       1
# 3             3  38_5718_20170914204352.wav         小来怎么没有天气预报了       1
# 4             4  38_5718_20170915092858.wav          你告诉我今天珠海天气       1
# ..          ...                         ...                 ...     ...
# 295         295  38_5718_20170914204639.wav              拨打李总电话       0
# 296         296  38_5716_20170914202341.wav                文昌空气       0
# 297         297  38_5718_20170914201846.wav            很想听音乐修今生       0
# 298         298  38_5718_20170914194315.wav          原来你只是报天气的呀       0
# 299         299  38_5716_20170914202603.wav    不要太多只要几首就好听太多懒得听       0
#
#      predicts
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1
# ...

# %%
import numpy as np

# %%
y_pred = []
for i in range(len(df["labels"])):
  y_pred.append(df["predicts"][i])
print(len(y_pred))

y_true = []
for i in range(len(df["labels"])):
   y_true.append(df["labels"][i])

print(len(y_true))

y_true = np.array(y_true)
y_pred = np.array(y_pred)
# Out:
# 300
# 300

# %%
from sklearn.metrics import recall_score
recall_score(y_true, y_pred)
# Out:
# 0.84

# %%
from sklearn.metrics import precision_score
precision_score(y_true, y_pred, average='macro')
# Out:
# 0.9310344827586207

# %%
from sklearn.metrics import f1_score
f1_score(y_true, y_pred, average='macro')
# Out:
# 0.9194847020933978
